# %%
import random

employees= range(400) #number of employees
gender= [random.choice(["female", "male"])for _ in employees] #randamly choose gender of all the employees
salary = [random.randint(7500, 30000) for _ in employees] #randomly input employee salary as interger between 7500 and 30000
workers_detail = []
employee_level = ["A5-F", "A1" ] #list of employee_level
for i in employees: #for loop
    try: #Exception handling

        #conditional statement to determine employee level
        if salary[i] >= 1000 and salary[i] <= 20000:
            employee_level = "A1"
        elif 7500 <= salary[i] <= 30000 and gender [i] == "female":
            employee_level = "A5-F"
        else:
            employee_level = "unclassified" #default level if no condition match

        paystamp = {'employees': employees[i], 'gender': gender[i],'salary': salary[i],'employee_level' :employee_level} #create dictionary with employee information

        workers_detail.append(paystamp)  # Append worker details to the list

    except Exception as e:
        print(f'Error processing employee: {str(e)}')

for paystamp in workers_detail: #print details of the employee paystamp
    print(paystamp)
# Out:
# {'employees': 0, 'gender': 'female', 'salary': 9408, 'employee_level': 'A1'}
# {'employees': 1, 'gender': 'male', 'salary': 20434, 'employee_level': 'unclassified'}
# {'employees': 2, 'gender': 'male', 'salary': 20185, 'employee_level': 'unclassified'}
# {'employees': 3, 'gender': 'male', 'salary': 26431, 'employee_level': 'unclassified'}
# {'employees': 4, 'gender': 'female', 'salary': 13078, 'employee_level': 'A1'}
# {'employees': 5, 'gender': 'female', 'salary': 14038, 'employee_level': 'A1'}
# {'employees': 6, 'gender': 'female', 'salary': 21885, 'employee_level': 'A5-F'}
# {'employees': 7, 'gender': 'female', 'salary': 15527, 'employee_level': 'A1'}
# {'employees': 8, 'gender': 'male', 'salary': 12363, 'employee_level': 'A1'}
# {'employees': 9, 'gender': 'female', 'salary': 28666, 'employee_level': 'A5-F'}
# {'employees': 10, 'gender': 'male', 'salary': 21363, 'employee_level': 'unclassified'}
# {'employees': 11, 'gender': 'male', 'salary': 17619, 'employee_level': 'A1'}
# {'employees': 12, 'gender': 'female', 'salary': 28857, 'employee_level': 'A5-F'}
# {'employees': 13, 'gender': 'male', 'salary': 25406, 'employee_level': 'unclassified'}
# {'employees': 14, 'gender': 'female', 'salary': 16581, 'employee_level': 'A1'}
# {'employees': 15, 'gender': 'male', 'salary': 17831, 'employee_level': 'A1'}
# {'employees': 16, 'gender': 'female', 'salary': 19370, 'employee_level': 'A1'}
# {'employees': 17, 'gender': 'female', 'salary': 24724, 'employee_level': 'A5-F'}
# {'employees': 18, 'gender': 'male', 'salary': 20465, 'employee_level': 'unclassified'}
# {'employees': 19, 'gender': 'female', 'salary': 21355, 'employee_level': 'A5-F'}
# {'employees': 20, 'gender': 'male', 'salary': 15138, 'employee_level': 'A1'}
# {'employees': 21, 'gender': 'male', 'salary': 8385, 'employee_level': 'A1'}
# {'employees': 22, 'gender': 'female', 'salary': 13872, 'employee_level': 'A1'}
# {'employees': 23, 'gender': 'male', 'salary': 16951, 'employee_level': 'A1'}
# {'employees': 24, 'gender': 'female', 'salary': 26780, 'employee_level': 'A5-F'}
# {'employees': 25, 'gender': 'female', 'salary': 24587, 'employee_level': 'A5-F'}
# {'employees': 26, 'gender': 'male', 'salary': 21523, 'employee_level': 'unclassified'}
# {'employees': 27, 'gender': 'female', 'salary': 20182, 'employee_level': 'A5-F'}
# {'employees': 28, 'gender': 'male', 'salary': 29441, 'employee_level': 'unclassified'}
# {'employees': 29, 'gender': 'male', 'salary': 14233, 'employee_level': 'A1'}
# {'employees': 30, 'gender': 'male', 'salary': 22868, 'employee_level': 'unclassified'}
# {'employees': 31, 'gender': 'male', 'salary': 9724, 'employee_level': 'A1'}
# {'employees': 32, 'gender': 'female', 'salary': 25444, 'employee_level': 'A5-F'}
# {'employees': 33, 'gender': 'female', 'salary': 23481, 'employee_level': 'A5-F'}
# {'employees': 34, 'gender': 'male', 'salary': 27045, 'employee_level': 'unclassified'}
# {'employees': 35, 'gender': 'male', 'salary': 13341, 'employee_level': 'A1'}
# {'employees': 36, 'gender': 'female', 'salary': 28010, 'employee_level': 'A5-F'}
# {'employees': 37, 'gender': 'female', 'salary': 24860, 'employee_level': 'A5-F'}
# {'employees': 38, 'gender': 'male', 'salary': 14538, 'employee_level': 'A1'}
# {'employees': 39, 'gender': 'female', 'salary': 19520, 'employee_level': 'A1'}
# {'employees': 40, 'gender': 'male', 'salary': 14058, 'employee_level': 'A1'}
# {'employees': 41, 'gender': 'female', 'salary': 22879, 'employee_level': 'A5-F'}
# {'employees': 42, 'gender': 'male', 'salary': 9602, 'employee_level': 'A1'}
# {'employees': 43, 'gender': 'female', 'salary': 9052, 'employee_level': 'A1'}
# {'employees': 44, 'gender': 'male', 'salary': 10186, 'employee_level': 'A1'}
# {'employees': 45, 'gender': 'female', 'salary': 17071, 'employee_level': 'A1'}
# {'employees': 46, 'gender': 'male', 'salary': 17378, 'employee_level': 'A1'}
# {'employees': 47, 'gender': 'female', 'salary': 23362, 'employee_level': 'A5-F'}
# {'employees': 48, 'gender': 'female', 'salary': 25250, 'employee_level': 'A5-F'}
# {'employees': 49, 'gender': 'female', 'salary': 15731, 'employee_level': 'A1'}
# {'employees': 50, 'gender': 'male', 'salary': 24667, 'employee_level': 'unclassified'}
# {'employees': 51, 'gender': 'female', 'salary': 15282, 'employee_level': 'A1'}
# {'employees': 52, 'gender': 'male', 'salary': 9339, 'employee_level': 'A1'}
# {'employees': 53, 'gender': 'female', 'salary': 16711, 'employee_level': 'A1'}
# {'employees': 54, 'gender': 'female', 'salary': 17786, 'employee_level': 'A1'}
# {'employees': 55, 'gender': 'male', 'salary': 19679, 'employee_level': 'A1'}
# {'employees': 56, 'gender': 'female', 'salary': 23778, 'employee_level': 'A5-F'}
# {'employees': 57, 'gender': 'male', 'salary': 17202, 'employee_level': 'A1'}
# {'employees': 58, 'gender': 'female', 'salary': 24388, 'employee_level': 'A5-F'}
# {'employees': 59, 'gender': 'female', 'salary': 27864, 'employee_level': 'A5-F'}
# {'employees': 60, 'gender': 'male', 'salary': 27984, 'employee_level': 'unclassified'}
# {'employees': 61, 'gender': 'male', 'salary': 11965, 'employee_level': 'A1'}
# {'employees': 62, 'gender': 'female', 'salary': 21284, 'employee_level': 'A5-F'}
# {'employees': 63, 'gender': 'male', 'salary': 28612, 'employee_level': 'unclassified'}
# {'employees': 64, 'gender': 'male', 'salary': 21014, 'employee_level': 'unclassified'}
# {'employees': 65, 'gender': 'female', 'salary': 13363, 'employee_level': 'A1'}
# {'employees': 66, 'gender': 'female', 'salary': 15206, 'employee_level': 'A1'}
# {'employees': 67, 'gender': 'female', 'salary': 29102, 'employee_level': 'A5-F'}
# {'employees': 68, 'gender': 'female', 'salary': 24712, 'employee_level': 'A5-F'}
# {'employees': 69, 'gender': 'male', 'salary': 23944, 'employee_level': 'unclassified'}
# {'employees': 70, 'gender': 'female', 'salary': 14380, 'employee_level': 'A1'}
# {'employees': 71, 'gender': 'female', 'salary': 20707, 'employee_level': 'A5-F'}
# {'employees': 72, 'gender': 'female', 'salary': 8219, 'employee_level': 'A1'}
# {'employees': 73, 'gender': 'male', 'salary': 13468, 'employee_level': 'A1'}
# {'employees': 74, 'gender': 'female', 'salary': 26387, 'employee_level': 'A5-F'}
# {'employees': 75, 'gender': 'female', 'salary': 8758, 'employee_level': 'A1'}
# {'employees': 76, 'gender': 'female', 'salary': 17492, 'employee_level': 'A1'}
# {'employees': 77, 'gender': 'male', 'salary': 21592, 'employee_level': 'unclassified'}
# {'employees': 78, 'gender': 'female', 'salary': 18680, 'employee_level': 'A1'}
# {'employees': 79, 'gender': 'male', 'salary': 22174, 'employee_level': 'unclassified'}
# {'employees': 80, 'gender': 'female', 'salary': 15702, 'employee_level': 'A1'}
# {'employees': 81, 'gender': 'female', 'salary': 18323, 'employee_level': 'A1'}
# {'employees': 82, 'gender': 'female', 'salary': 25645, 'employee_level': 'A5-F'}
# {'employees': 83, 'gender': 'female', 'salary': 10807, 'employee_level': 'A1'}
# {'employees': 84, 'gender': 'female', 'salary': 14129, 'employee_level': 'A1'}
# {'employees': 85, 'gender': 'female', 'salary': 24677, 'employee_level': 'A5-F'}
# {'employees': 86, 'gender': 'male', 'salary': 12616, 'employee_level': 'A1'}
# {'employees': 87, 'gender': 'male', 'salary': 21768, 'employee_level': 'unclassified'}
# {'employees': 88, 'gender': 'female', 'salary': 20540, 'employee_level': 'A5-F'}
# {'employees': 89, 'gender': 'female', 'salary': 15618, 'employee_level': 'A1'}
# {'employees': 90, 'gender': 'female', 'salary': 24710, 'employee_level': 'A5-F'}
# {'employees': 91, 'gender': 'male', 'salary': 15241, 'employee_level': 'A1'}
# {'employees': 92, 'gender': 'male', 'salary': 23863, 'employee_level': 'unclassified'}
# {'employees': 93, 'gender': 'female', 'salary': 12504, 'employee_level': 'A1'}
# {'employees': 94, 'gender': 'female', 'salary': 13113, 'employee_level': 'A1'}
# {'employees': 95, 'gender': 'female', 'salary': 15620, 'employee_level': 'A1'}
# {'employees': 96, 'gender': 'female', 'salary': 22039, 'employee_level': 'A5-F'}
# {'employees': 97, 'gender': 'male', 'salary': 10430, 'employee_level': 'A1'}
# {'employees': 98, 'gender': 'female', 'salary': 16058, 'employee_level': 'A1'}
# {'employees': 99, 'gender': 'female', 'salary': 14361, 'employee_level': 'A1'}
# {'employees': 100, 'gender': 'female', 'salary': 21844, 'employee_level': 'A5-F'}
# {'employees': 101, 'gender': 'male', 'salary': 27619, 'employee_level': 'unclassified'}
# {'employees': 102, 'gender': 'female', 'salary': 26877, 'employee_level': 'A5-F'}
# {'employees': 103, 'gender': 'female', 'salary': 12606, 'employee_level': 'A1'}
# {'employees': 104, 'gender': 'female', 'salary': 12949, 'employee_level': 'A1'}
# {'employees': 105, 'gender': 'male', 'salary': 20378, 'employee_level': 'unclassified'}
# {'employees': 106, 'gender': 'male', 'salary': 12663, 'employee_level': 'A1'}
# {'employees': 107, 'gender': 'female', 'salary': 21770, 'employee_level': 'A5-F'}
# {'employees': 108, 'gender': 'male', 'salary': 13172, 'employee_level': 'A1'}
# {'employees': 109, 'gender': 'male', 'salary': 22533, 'employee_level': 'unclassified'}
# {'employees': 110, 'gender': 'male', 'salary': 20789, 'employee_level': 'unclassified'}
# {'employees': 111, 'gender': 'female', 'salary': 21581, 'employee_level': 'A5-F'}
# {'employees': 112, 'gender': 'female', 'salary': 9722, 'employee_level': 'A1'}
# {'employees': 113, 'gender': 'female', 'salary': 27555, 'employee_level': 'A5-F'}
# {'employees': 114, 'gender': 'male', 'salary': 21373, 'employee_level': 'unclassified'}
# {'employees': 115, 'gender': 'female', 'salary': 23475, 'employee_level': 'A5-F'}
# {'employees': 116, 'gender': 'female', 'salary': 15388, 'employee_level': 'A1'}
# {'employees': 117, 'gender': 'female', 'salary': 18584, 'employee_level': 'A1'}
# {'employees': 118, 'gender': 'male', 'salary': 26086, 'employee_level': 'unclassified'}
# {'employees': 119, 'gender': 'male', 'salary': 11149, 'employee_level': 'A1'}
# {'employees': 120, 'gender': 'male', 'salary': 9405, 'employee_level': 'A1'}
# {'employees': 121, 'gender': 'male', 'salary': 16420, 'employee_level': 'A1'}
# {'employees': 122, 'gender': 'male', 'salary': 10918, 'employee_level': 'A1'}
# {'employees': 123, 'gender': 'female', 'salary': 9247, 'employee_level': 'A1'}
# {'employees': 124, 'gender': 'female', 'salary': 12983, 'employee_level': 'A1'}
# {'employees': 125, 'gender': 'female', 'salary': 25228, 'employee_level': 'A5-F'}
# {'employees': 126, 'gender': 'male', 'salary': 19249, 'employee_level': 'A1'}
# {'employees': 127, 'gender': 'male', 'salary': 12432, 'employee_level': 'A1'}
# {'employees': 128, 'gender': 'female', 'salary': 27328, 'employee_level': 'A5-F'}
# {'employees': 129, 'gender': 'female', 'salary': 20271, 'employee_level': 'A5-F'}
# {'employees': 130, 'gender': 'male', 'salary': 17893, 'employee_level': 'A1'}
# {'employees': 131, 'gender': 'female', 'salary': 22186, 'employee_level': 'A5-F'}
# {'employees': 132, 'gender': 'male', 'salary': 11819, 'employee_level': 'A1'}
# {'employees': 133, 'gender': 'female', 'salary': 27562, 'employee_level': 'A5-F'}
# {'employees': 134, 'gender': 'female', 'salary': 17998, 'employee_level': 'A1'}
# {'employees': 135, 'gender': 'female', 'salary': 18043, 'employee_level': 'A1'}
# {'employees': 136, 'gender': 'female', 'salary': 21264, 'employee_level': 'A5-F'}
# {'employees': 137, 'gender': 'female', 'salary': 9461, 'employee_level': 'A1'}
# {'employees': 138, 'gender': 'female', 'salary': 27566, 'employee_level': 'A5-F'}
# {'employees': 139, 'gender': 'female', 'salary': 23617, 'employee_level': 'A5-F'}
# {'employees': 140, 'gender': 'male', 'salary': 9375, 'employee_level': 'A1'}
# {'employees': 141, 'gender': 'male', 'salary': 8499, 'employee_level': 'A1'}
# {'employees': 142, 'gender': 'female', 'salary': 16492, 'employee_level': 'A1'}
# {'employees': 143, 'gender': 'female', 'salary': 27593, 'employee_level': 'A5-F'}
# {'employees': 144, 'gender': 'female', 'salary': 20629, 'employee_level': 'A5-F'}
# {'employees': 145, 'gender': 'female', 'salary': 17757, 'employee_level': 'A1'}
# {'employees': 146, 'gender': 'male', 'salary': 9628, 'employee_level': 'A1'}
# {'employees': 147, 'gender': 'female', 'salary': 24328, 'employee_level': 'A5-F'}
# {'employees': 148, 'gender': 'female', 'salary': 23188, 'employee_level': 'A5-F'}
# {'employees': 149, 'gender': 'female', 'salary': 23542, 'employee_level': 'A5-F'}
# {'employees': 150, 'gender': 'male', 'salary': 28787, 'employee_level': 'unclassified'}
# {'employees': 151, 'gender': 'female', 'salary': 28405, 'employee_level': 'A5-F'}
# {'employees': 152, 'gender': 'female', 'salary': 26397, 'employee_level': 'A5-F'}
# {'employees': 153, 'gender': 'female', 'salary': 16933, 'employee_level': 'A1'}
# {'employees': 154, 'gender': 'male', 'salary': 10802, 'employee_level': 'A1'}
# {'employees': 155, 'gender': 'female', 'salary': 28021, 'employee_level': 'A5-F'}
# {'employees': 156, 'gender': 'male', 'salary': 17050, 'employee_level': 'A1'}
# {'employees': 157, 'gender': 'female', 'salary': 24745, 'employee_level': 'A5-F'}
# {'employees': 158, 'gender': 'male', 'salary': 29183, 'employee_level': 'unclassified'}
# {'employees': 159, 'gender': 'female', 'salary': 8871, 'employee_level': 'A1'}
# {'employees': 160, 'gender': 'female', 'salary': 21148, 'employee_level': 'A5-F'}
# {'employees': 161, 'gender': 'female', 'salary': 14775, 'employee_level': 'A1'}
# {'employees': 162, 'gender': 'female', 'salary': 11541, 'employee_level': 'A1'}
# {'employees': 163, 'gender': 'female', 'salary': 13031, 'employee_level': 'A1'}
# {'employees': 164, 'gender': 'female', 'salary': 13339, 'employee_level': 'A1'}
# {'employees': 165, 'gender': 'male', 'salary': 17518, 'employee_level': 'A1'}
# {'employees': 166, 'gender': 'female', 'salary': 9122, 'employee_level': 'A1'}
# {'employees': 167, 'gender': 'female', 'salary': 19274, 'employee_level': 'A1'}
# {'employees': 168, 'gender': 'female', 'salary': 22555, 'employee_level': 'A5-F'}
# {'employees': 169, 'gender': 'male', 'salary': 14432, 'employee_level': 'A1'}
# {'employees': 170, 'gender': 'male', 'salary': 16915, 'employee_level': 'A1'}
# {'employees': 171, 'gender': 'male', 'salary': 29718, 'employee_level': 'unclassified'}
# {'employees': 172, 'gender': 'male', 'salary': 21976, 'employee_level': 'unclassified'}
# {'employees': 173, 'gender': 'female', 'salary': 16765, 'employee_level': 'A1'}
# {'employees': 174, 'gender': 'female', 'salary': 7884, 'employee_level': 'A1'}
# {'employees': 175, 'gender': 'male', 'salary': 21082, 'employee_level': 'unclassified'}
# {'employees': 176, 'gender': 'male', 'salary': 14638, 'employee_level': 'A1'}
# {'employees': 177, 'gender': 'male', 'salary': 21037, 'employee_level': 'unclassified'}
# {'employees': 178, 'gender': 'male', 'salary': 20782, 'employee_level': 'unclassified'}
# {'employees': 179, 'gender': 'female', 'salary': 11142, 'employee_level': 'A1'}
# {'employees': 180, 'gender': 'male', 'salary': 12732, 'employee_level': 'A1'}
# {'employees': 181, 'gender': 'male', 'salary': 27969, 'employee_level': 'unclassified'}
# {'employees': 182, 'gender': 'male', 'salary': 17808, 'employee_level': 'A1'}
# {'employees': 183, 'gender': 'female', 'salary': 15426, 'employee_level': 'A1'}
# {'employees': 184, 'gender': 'male', 'salary': 14089, 'employee_level': 'A1'}
# {'employees': 185, 'gender': 'male', 'salary': 27929, 'employee_level': 'unclassified'}
# {'employees': 186, 'gender': 'female', 'salary': 26133, 'employee_level': 'A5-F'}
# {'employees': 187, 'gender': 'female', 'salary': 13506, 'employee_level': 'A1'}
# {'employees': 188, 'gender': 'female', 'salary': 28647, 'employee_level': 'A5-F'}
# {'employees': 189, 'gender': 'male', 'salary': 25705, 'employee_level': 'unclassified'}
# {'employees': 190, 'gender': 'male', 'salary': 24908, 'employee_level': 'unclassified'}
# {'employees': 191, 'gender': 'male', 'salary': 25575, 'employee_level': 'unclassified'}
# {'employees': 192, 'gender': 'male', 'salary': 29150, 'employee_level': 'unclassified'}
# {'employees': 193, 'gender': 'female', 'salary': 22169, 'employee_level': 'A5-F'}
# {'employees': 194, 'gender': 'male', 'salary': 14084, 'employee_level': 'A1'}
# {'employees': 195, 'gender': 'male', 'salary': 28075, 'employee_level': 'unclassified'}
# {'employees': 196, 'gender': 'female', 'salary': 12826, 'employee_level': 'A1'}
# {'employees': 197, 'gender': 'male', 'salary': 27370, 'employee_level': 'unclassified'}
# {'employees': 198, 'gender': 'male', 'salary': 28873, 'employee_level': 'unclassified'}
# {'employees': 199, 'gender': 'female', 'salary': 9600, 'employee_level': 'A1'}
# {'employees': 200, 'gender': 'male', 'salary': 24817, 'employee_level': 'unclassified'}
# {'employees': 201, 'gender': 'male', 'salary': 18528, 'employee_level': 'A1'}
# {'employees': 202, 'gender': 'male', 'salary': 18060, 'employee_level': 'A1'}
# {'employees': 203, 'gender': 'male', 'salary': 18388, 'employee_level': 'A1'}
# {'employees': 204, 'gender': 'male', 'salary': 11249, 'employee_level': 'A1'}
# {'employees': 205, 'gender': 'male', 'salary': 26069, 'employee_level': 'unclassified'}
# {'employees': 206, 'gender': 'male', 'salary': 28898, 'employee_level': 'unclassified'}
# {'employees': 207, 'gender': 'male', 'salary': 28159, 'employee_level': 'unclassified'}
# {'employees': 208, 'gender': 'male', 'salary': 16648, 'employee_level': 'A1'}
# {'employees': 209, 'gender': 'female', 'salary': 20201, 'employee_level': 'A5-F'}
# {'employees': 210, 'gender': 'male', 'salary': 21029, 'employee_level': 'unclassified'}
# {'employees': 211, 'gender': 'male', 'salary': 29305, 'employee_level': 'unclassified'}
# {'employees': 212, 'gender': 'female', 'salary': 12453, 'employee_level': 'A1'}
# {'employees': 213, 'gender': 'male', 'salary': 14474, 'employee_level': 'A1'}
# {'employees': 214, 'gender': 'male', 'salary': 26114, 'employee_level': 'unclassified'}
# {'employees': 215, 'gender': 'male', 'salary': 18920, 'employee_level': 'A1'}
# {'employees': 216, 'gender': 'male', 'salary': 8502, 'employee_level': 'A1'}
# {'employees': 217, 'gender': 'female', 'salary': 23160, 'employee_level': 'A5-F'}
# {'employees': 218, 'gender': 'male', 'salary': 29941, 'employee_level': 'unclassified'}
# {'employees': 219, 'gender': 'female', 'salary': 7563, 'employee_level': 'A1'}
# {'employees': 220, 'gender': 'female', 'salary': 20903, 'employee_level': 'A5-F'}
# {'employees': 221, 'gender': 'male', 'salary': 17853, 'employee_level': 'A1'}
# {'employees': 222, 'gender': 'male', 'salary': 24271, 'employee_level': 'unclassified'}
# {'employees': 223, 'gender': 'male', 'salary': 16288, 'employee_level': 'A1'}
# {'employees': 224, 'gender': 'male', 'salary': 16241, 'employee_level': 'A1'}
# {'employees': 225, 'gender': 'male', 'salary': 15309, 'employee_level': 'A1'}
# {'employees': 226, 'gender': 'male', 'salary': 27737, 'employee_level': 'unclassified'}
# {'employees': 227, 'gender': 'male', 'salary': 23486, 'employee_level': 'unclassified'}
# {'employees': 228, 'gender': 'female', 'salary': 23123, 'employee_level': 'A5-F'}
# {'employees': 229, 'gender': 'male', 'salary': 26300, 'employee_level': 'unclassified'}
# {'employees': 230, 'gender': 'female', 'salary': 16520, 'employee_level': 'A1'}
# {'employees': 231, 'gender': 'female', 'salary': 17740, 'employee_level': 'A1'}
# {'employees': 232, 'gender': 'female', 'salary': 19769, 'employee_level': 'A1'}
# {'employees': 233, 'gender': 'male', 'salary': 16765, 'employee_level': 'A1'}
# {'employees': 234, 'gender': 'male', 'salary': 20520, 'employee_level': 'unclassified'}
# {'employees': 235, 'gender': 'male', 'salary': 28555, 'employee_level': 'unclassified'}
# {'employees': 236, 'gender': 'male', 'salary': 23449, 'employee_level': 'unclassified'}
# {'employees': 237, 'gender': 'male', 'salary': 28727, 'employee_level': 'unclassified'}
# {'employees': 238, 'gender': 'female', 'salary': 12505, 'employee_level': 'A1'}
# {'employees': 239, 'gender': 'male', 'salary': 26376, 'employee_level': 'unclassified'}
# {'employees': 240, 'gender': 'female', 'salary': 14144, 'employee_level': 'A1'}
# {'employees': 241, 'gender': 'female', 'salary': 20592, 'employee_level': 'A5-F'}
# {'employees': 242, 'gender': 'female', 'salary': 12069, 'employee_level': 'A1'}
# {'employees': 243, 'gender': 'male', 'salary': 27574, 'employee_level': 'unclassified'}
# {'employees': 244, 'gender': 'female', 'salary': 16892, 'employee_level': 'A1'}
# {'employees': 245, 'gender': 'female', 'salary': 22216, 'employee_level': 'A5-F'}
# {'employees': 246, 'gender': 'female', 'salary': 24356, 'employee_level': 'A5-F'}
# {'employees': 247, 'gender': 'male', 'salary': 24989, 'employee_level': 'unclassified'}
# {'employees': 248, 'gender': 'female', 'salary': 10266, 'employee_level': 'A1'}
# {'employees': 249, 'gender': 'male', 'salary': 28991, 'employee_level': 'unclassified'}
# {'employees': 250, 'gender': 'female', 'salary': 18076, 'employee_level': 'A1'}
# {'employees': 251, 'gender': 'male', 'salary': 16335, 'employee_level': 'A1'}
# {'employees': 252, 'gender': 'male', 'salary': 16032, 'employee_level': 'A1'}
# {'employees': 253, 'gender': 'female', 'salary': 14959, 'employee_level': 'A1'}
# {'employees': 254, 'gender': 'male', 'salary': 25114, 'employee_level': 'unclassified'}
# {'employees': 255, 'gender': 'female', 'salary': 20200, 'employee_level': 'A5-F'}
# {'employees': 256, 'gender': 'female', 'salary': 28851, 'employee_level': 'A5-F'}
# {'employees': 257, 'gender': 'female', 'salary': 11429, 'employee_level': 'A1'}
# {'employees': 258, 'gender': 'female', 'salary': 16060, 'employee_level': 'A1'}
# {'employees': 259, 'gender': 'female', 'salary': 15199, 'employee_level': 'A1'}
# {'employees': 260, 'gender': 'female', 'salary': 14870, 'employee_level': 'A1'}
# {'employees': 261, 'gender': 'female', 'salary': 15233, 'employee_level': 'A1'}
# {'employees': 262, 'gender': 'male', 'salary': 16689, 'employee_level': 'A1'}
# {'employees': 263, 'gender': 'male', 'salary': 28828, 'employee_level': 'unclassified'}
# {'employees': 264, 'gender': 'male', 'salary': 15553, 'employee_level': 'A1'}
# {'employees': 265, 'gender': 'female', 'salary': 22018, 'employee_level': 'A5-F'}
# {'employees': 266, 'gender': 'male', 'salary': 20943, 'employee_level': 'unclassified'}
# {'employees': 267, 'gender': 'male', 'salary': 15507, 'employee_level': 'A1'}
# {'employees': 268, 'gender': 'female', 'salary': 28475, 'employee_level': 'A5-F'}
# {'employees': 269, 'gender': 'male', 'salary': 22896, 'employee_level': 'unclassified'}
# {'employees': 270, 'gender': 'female', 'salary': 28993, 'employee_level': 'A5-F'}
# {'employees': 271, 'gender': 'male', 'salary': 24582, 'employee_level': 'unclassified'}
# {'employees': 272, 'gender': 'female', 'salary': 28235, 'employee_level': 'A5-F'}
# {'employees': 273, 'gender': 'male', 'salary': 22168, 'employee_level': 'unclassified'}
# {'employees': 274, 'gender': 'male', 'salary': 18585, 'employee_level': 'A1'}
# {'employees': 275, 'gender': 'male', 'salary': 18129, 'employee_level': 'A1'}
# {'employees': 276, 'gender': 'male', 'salary': 23808, 'employee_level': 'unclassified'}
# {'employees': 277, 'gender': 'male', 'salary': 8123, 'employee_level': 'A1'}
# {'employees': 278, 'gender': 'male', 'salary': 22645, 'employee_level': 'unclassified'}
# {'employees': 279, 'gender': 'female', 'salary': 8168, 'employee_level': 'A1'}
# {'employees': 280, 'gender': 'female', 'salary': 11590, 'employee_level': 'A1'}
# {'employees': 281, 'gender': 'male', 'salary': 13958, 'employee_level': 'A1'}
# {'employees': 282, 'gender': 'female', 'salary': 13795, 'employee_level': 'A1'}
# {'employees': 283, 'gender': 'male', 'salary': 12845, 'employee_level': 'A1'}
# {'employees': 284, 'gender': 'female', 'salary': 8275, 'employee_level': 'A1'}
# {'employees': 285, 'gender': 'male', 'salary': 7590, 'employee_level': 'A1'}
# {'employees': 286, 'gender': 'female', 'salary': 15906, 'employee_level': 'A1'}
# {'employees': 287, 'gender': 'female', 'salary': 25749, 'employee_level': 'A5-F'}
# {'employees': 288, 'gender': 'male', 'salary': 19093, 'employee_level': 'A1'}
# {'employees': 289, 'gender': 'female', 'salary': 9812, 'employee_level': 'A1'}
# {'employees': 290, 'gender': 'female', 'salary': 23187, 'employee_level': 'A5-F'}
# {'employees': 291, 'gender': 'female', 'salary': 22373, 'employee_level': 'A5-F'}
# {'employees': 292, 'gender': 'female', 'salary': 8356, 'employee_level': 'A1'}
# {'employees': 293, 'gender': 'female', 'salary': 22456, 'employee_level': 'A5-F'}
# {'employees': 294, 'gender': 'male', 'salary': 9920, 'employee_level': 'A1'}
# {'employees': 295, 'gender': 'female', 'salary': 20537, 'employee_level': 'A5-F'}
# {'employees': 296, 'gender': 'female', 'salary': 20508, 'employee_level': 'A5-F'}
# {'employees': 297, 'gender': 'female', 'salary': 11127, 'employee_level': 'A1'}
# {'employees': 298, 'gender': 'female', 'salary': 9319, 'employee_level': 'A1'}
# {'employees': 299, 'gender': 'female', 'salary': 22271, 'employee_level': 'A5-F'}
# {'employees': 300, 'gender': 'female', 'salary': 27864, 'employee_level': 'A5-F'}
# {'employees': 301, 'gender': 'female', 'salary': 19157, 'employee_level': 'A1'}
# {'employees': 302, 'gender': 'female', 'salary': 22962, 'employee_level': 'A5-F'}
# {'employees': 303, 'gender': 'female', 'salary': 10537, 'employee_level': 'A1'}
# {'employees': 304, 'gender': 'male', 'salary': 15042, 'employee_level': 'A1'}
# {'employees': 305, 'gender': 'male', 'salary': 26154, 'employee_level': 'unclassified'}
# {'employees': 306, 'gender': 'male', 'salary': 27985, 'employee_level': 'unclassified'}
# {'employees': 307, 'gender': 'male', 'salary': 28628, 'employee_level': 'unclassified'}
# {'employees': 308, 'gender': 'female', 'salary': 25443, 'employee_level': 'A5-F'}
# {'employees': 309, 'gender': 'male', 'salary': 14414, 'employee_level': 'A1'}
# {'employees': 310, 'gender': 'female', 'salary': 21749, 'employee_level': 'A5-F'}
# {'employees': 311, 'gender': 'female', 'salary': 28790, 'employee_level': 'A5-F'}
# {'employees': 312, 'gender': 'male', 'salary': 8212, 'employee_level': 'A1'}
# {'employees': 313, 'gender': 'female', 'salary': 14023, 'employee_level': 'A1'}
# {'employees': 314, 'gender': 'female', 'salary': 18684, 'employee_level': 'A1'}
# {'employees': 315, 'gender': 'female', 'salary': 26288, 'employee_level': 'A5-F'}
# {'employees': 316, 'gender': 'male', 'salary': 24057, 'employee_level': 'unclassified'}
# {'employees': 317, 'gender': 'female', 'salary': 18617, 'employee_level': 'A1'}
# {'employees': 318, 'gender': 'male', 'salary': 10749, 'employee_level': 'A1'}
# {'employees': 319, 'gender': 'female', 'salary': 29552, 'employee_level': 'A5-F'}
# {'employees': 320, 'gender': 'female', 'salary': 17018, 'employee_level': 'A1'}
# {'employees': 321, 'gender': 'female', 'salary': 17235, 'employee_level': 'A1'}
# {'employees': 322, 'gender': 'male', 'salary': 27211, 'employee_level': 'unclassified'}
# {'employees': 323, 'gender': 'female', 'salary': 16116, 'employee_level': 'A1'}
# {'employees': 324, 'gender': 'male', 'salary': 10802, 'employee_level': 'A1'}
# {'employees': 325, 'gender': 'female', 'salary': 19721, 'employee_level': 'A1'}
# {'employees': 326, 'gender': 'male', 'salary': 14904, 'employee_level': 'A1'}
# {'employees': 327, 'gender': 'female', 'salary': 18497, 'employee_level': 'A1'}
# {'employees': 328, 'gender': 'female', 'salary': 7745, 'employee_level': 'A1'}
# {'employees': 329, 'gender': 'male', 'salary': 20145, 'employee_level': 'unclassified'}
# {'employees': 330, 'gender': 'male', 'salary': 9882, 'employee_level': 'A1'}
# {'employees': 331, 'gender': 'male', 'salary': 17726, 'employee_level': 'A1'}
# {'employees': 332, 'gender': 'male', 'salary': 29157, 'employee_level': 'unclassified'}
# {'employees': 333, 'gender': 'male', 'salary': 8091, 'employee_level': 'A1'}
# {'employees': 334, 'gender': 'female', 'salary': 19008, 'employee_level': 'A1'}
# {'employees': 335, 'gender': 'male', 'salary': 16168, 'employee_level': 'A1'}
# {'employees': 336, 'gender': 'female', 'salary': 10953, 'employee_level': 'A1'}
# {'employees': 337, 'gender': 'female', 'salary': 16874, 'employee_level': 'A1'}
# {'employees': 338, 'gender': 'male', 'salary': 8656, 'employee_level': 'A1'}
# {'employees': 339, 'gender': 'male', 'salary': 13585, 'employee_level': 'A1'}
# {'employees': 340, 'gender': 'male', 'salary': 11695, 'employee_level': 'A1'}
# {'employees': 341, 'gender': 'male', 'salary': 19005, 'employee_level': 'A1'}
# {'employees': 342, 'gender': 'male', 'salary': 11265, 'employee_level': 'A1'}
# {'employees': 343, 'gender': 'female', 'salary': 8020, 'employee_level': 'A1'}
# {'employees': 344, 'gender': 'male', 'salary': 29257, 'employee_level': 'unclassified'}
# {'employees': 345, 'gender': 'male', 'salary': 9959, 'employee_level': 'A1'}
# {'employees': 346, 'gender': 'female', 'salary': 20189, 'employee_level': 'A5-F'}
# {'employees': 347, 'gender': 'male', 'salary': 23233, 'employee_level': 'unclassified'}
# {'employees': 348, 'gender': 'male', 'salary': 8540, 'employee_level': 'A1'}
# {'employees': 349, 'gender': 'male', 'salary': 26804, 'employee_level': 'unclassified'}
# {'employees': 350, 'gender': 'female', 'salary': 17581, 'employee_level': 'A1'}
# {'employees': 351, 'gender': 'female', 'salary': 13481, 'employee_level': 'A1'}
# {'employees': 352, 'gender': 'male', 'salary': 24716, 'employee_level': 'unclassified'}
# {'employees': 353, 'gender': 'male', 'salary': 11250, 'employee_level': 'A1'}
# {'employees': 354, 'gender': 'male', 'salary': 10650, 'employee_level': 'A1'}
# {'employees': 355, 'gender': 'female', 'salary': 7565, 'employee_level': 'A1'}
# {'employees': 356, 'gender': 'male', 'salary': 14452, 'employee_level': 'A1'}
# {'employees': 357, 'gender': 'male', 'salary': 10425, 'employee_level': 'A1'}
# {'employees': 358, 'gender': 'female', 'salary': 9733, 'employee_level': 'A1'}
# {'employees': 359, 'gender': 'female', 'salary': 22098, 'employee_level': 'A5-F'}
# {'employees': 360, 'gender': 'male', 'salary': 25221, 'employee_level': 'unclassified'}
# {'employees': 361, 'gender': 'female', 'salary': 27741, 'employee_level': 'A5-F'}
# {'employees': 362, 'gender': 'female', 'salary': 17777, 'employee_level': 'A1'}
# {'employees': 363, 'gender': 'female', 'salary': 25609, 'employee_level': 'A5-F'}
# {'employees': 364, 'gender': 'female', 'salary': 11583, 'employee_level': 'A1'}
# {'employees': 365, 'gender': 'male', 'salary': 16994, 'employee_level': 'A1'}
# {'employees': 366, 'gender': 'male', 'salary': 22662, 'employee_level': 'unclassified'}
# {'employees': 367, 'gender': 'female', 'salary': 14255, 'employee_level': 'A1'}
# {'employees': 368, 'gender': 'male', 'salary': 10686, 'employee_level': 'A1'}
# {'employees': 369, 'gender': 'female', 'salary': 20266, 'employee_level': 'A5-F'}
# {'employees': 370, 'gender': 'male', 'salary': 28059, 'employee_level': 'unclassified'}
# {'employees': 371, 'gender': 'male', 'salary': 29558, 'employee_level': 'unclassified'}
# {'employees': 372, 'gender': 'female', 'salary': 9456, 'employee_level': 'A1'}
# {'employees': 373, 'gender': 'male', 'salary': 27003, 'employee_level': 'unclassified'}
# {'employees': 374, 'gender': 'male', 'salary': 8517, 'employee_level': 'A1'}
# {'employees': 375, 'gender': 'female', 'salary': 15689, 'employee_level': 'A1'}
# {'employees': 376, 'gender': 'male', 'salary': 26044, 'employee_level': 'unclassified'}
# {'employees': 377, 'gender': 'female', 'salary': 14926, 'employee_level': 'A1'}
# {'employees': 378, 'gender': 'male', 'salary': 13087, 'employee_level': 'A1'}
# {'employees': 379, 'gender': 'female', 'salary': 21187, 'employee_level': 'A5-F'}
# {'employees': 380, 'gender': 'male', 'salary': 25278, 'employee_level': 'unclassified'}
# {'employees': 381, 'gender': 'female', 'salary': 27809, 'employee_level': 'A5-F'}
# {'employees': 382, 'gender': 'female', 'salary': 13614, 'employee_level': 'A1'}
# {'employees': 383, 'gender': 'female', 'salary': 13933, 'employee_level': 'A1'}
# {'employees': 384, 'gender': 'female', 'salary': 21962, 'employee_level': 'A5-F'}
# {'employees': 385, 'gender': 'male', 'salary': 13624, 'employee_level': 'A1'}
# {'employees': 386, 'gender': 'female', 'salary': 22876, 'employee_level': 'A5-F'}
# {'employees': 387, 'gender': 'female', 'salary': 22202, 'employee_level': 'A5-F'}
# {'employees': 388, 'gender': 'female', 'salary': 26668, 'employee_level': 'A5-F'}
# {'employees': 389, 'gender': 'female', 'salary': 25447, 'employee_level': 'A5-F'}
# {'employees': 390, 'gender': 'female', 'salary': 24140, 'employee_level': 'A5-F'}
# {'employees': 391, 'gender': 'female', 'salary': 16789, 'employee_level': 'A1'}
# {'employees': 392, 'gender': 'female', 'salary': 13625, 'employee_level': 'A1'}
# {'employees': 393, 'gender': 'female', 'salary': 8900, 'employee_level': 'A1'}
# {'employees': 394, 'gender': 'male', 'salary': 28742, 'employee_level': 'unclassified'}
# {'employees': 395, 'gender': 'female', 'salary': 18125, 'employee_level': 'A1'}
# {'employees': 396, 'gender': 'male', 'salary': 9825, 'employee_level': 'A1'}
# {'employees': 397, 'gender': 'male', 'salary': 18380, 'employee_level': 'A1'}
# {'employees': 398, 'gender': 'female', 'salary': 29490, 'employee_level': 'A5-F'}
# {'employees': 399, 'gender': 'male', 'salary': 8376, 'employee_level': 'A1'}
